# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Acquisition

# %%
review_df = pd.read_excel("../Datasets/digikala_farsi/Users_Comments.xlsx")
order_hist_df = pd.read_excel("../Datasets/digikala_farsi/Customer_Purchase_History.xlsx")
prod_quality_df = pd.read_excel("../Datasets/digikala_farsi/Product_Quality.xlsx")
prod_hist_df = pd.read_csv("../Datasets/digikala_farsi/Product_History.csv")
prod_df = pd.read_excel("../Datasets/digikala_farsi/Product_List.xlsx")

# %%
print(prod_df.columns)
print(prod_hist_df.columns)
print(prod_quality_df.columns)
print(order_hist_df.columns)
print(review_df.columns)
# Out:
# Index(['id', 'product_title_fa', 'product_title_en', 'url_code', 'title_alt',
#        'category_title_fa', 'category_keywords', 'brand_name_fa',
#        'brand_name_en', 'product_attributes'],
#       dtype='object')
# Index(['id;product_variant_id;selling_price;rrp_price;base_price;buy_price;order_limit;start_at;end_at;tags;show_in_price_history;active;created_at;product_id;marketplace_seller_id'], dtype='object')
# Index(['product_id', 'confirmed_at', 'comment'], dtype='object')
# Index(['order_id', 'user_id', 'variant_id', 'product_id', 'quantity', 'price',
#        'date', 'city_id', 'city_name', 'state_id', 'state_name'],
#       dtype='object')
# Index(['product_id', 'product_title', 'title_en', 'user_id', 'likes',
#        'dislikes', 'verification_status', 'recommend', 'title', 'comment',
#        'advantages', 'disadvantages'],
#       dtype='object')

# %%
prod_df.head()
# Out:
#        id                                   product_title_fa  \
# 0  723302            ماگ حرارتی لومانا مدل عرفانه کد MAG1042
# 1  727089       ست آبکش و آبگیر تیتیز مدل AP-9141 سایز متوسط
# 2  727096  روغن مرطوب کننده کدلی مدل Divine oil حجم 50 می...
# 3  727803  ست لحاف پوپلین هوبی مدل اما یکنفره چهار تکه کاوری
# 4  725222                         ماگ آبنبات رنگی مدل AR0143
#
#                          product_title_en  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3  Hobby Emma Quilt Single Set - 4 Pieces
# 4                                     NaN
#
#                                             url_code  \
# 0            ماگ-حرارتی-لومانا-مدل-عرفانه-کد-mag1042
# 1       ست-آبکش-و-آبگیر-تیتیز-مدل-ap-9141-سایز-متوسط
# 2  روغن-مرطوب-کننده-کدلی-مدل-divine-oil-حجم-50-می...
# 3  ست-لحاف-پوپلین-هوبی-مدل-اما-یکنفره-چهار-تکه-کاوری
# 4                         ماگ-آبنبات-رنگی-مدل-ar0143
#
# ...

# %%
review_df.drop(labels=[])
# Out:
#    product_id                product_title title_en  user_id  likes  dislikes  \
# 0        3692  ماوس بی‌سیم لاجیتک مدل M325       IT   989472      0         0
#
#   verification_status recommend title                            comment  \
# 0            verified        \N   NaN  واقعا عالیه. من که ازش خیلی راضیم
#
#   advantages disadvantages
# 0        NaN           NaN

# %%
review_df[review_df['product_id'] == 3692]
# Out:
#        product_id                product_title title_en  user_id  likes  \
# 0            3692  ماوس بی‌سیم لاجیتک مدل M325       IT   989472      0
# 56908        3692  ماوس بی‌سیم لاجیتک مدل M325       IT  2813503      0
#
#        dislikes verification_status    recommend       title  \
# 0             0            verified           \N         NaN
# 56908         0            verified  recommended  فوق العادس
#
#                                                  comment  \
# 0                      واقعا عالیه. من که ازش خیلی راضیم
# 56908  سال 95 خریدم و هنوز دارم استفاده میکنم . روزی ...
#
#                                               advantages disadvantages
# 0                                                    NaN           NaN
# 56908  ["خوش دست و کاربردی \r","مناسب برای گیم\r","مق...           NaN

# %%
review_df.sort_values(by=['likes'], ascending=False)
# Out:
#        product_id                                      product_title title_en  \
# 21288      698313      لپ تاپ 11 اینچی لنوو مدل Yoga 300-11IBR N3060       IT
# 17133      698313      لپ تاپ 11 اینچی لنوو مدل Yoga 300-11IBR N3060       IT
# 55079      818885           گوشی موبایل بلو مدل Grand M2 دو سیم کارت       MO
# 27624      643764                مچ بند هوشمند شیائومی مدل Mi Band 3       PA
# 55040      817489  گوشی موبایل اپل مدل iPhone XS Max دو سیم‌ کارت...       MO
# ...           ...                                                ...      ...
# 53174      348140        اسپیکر بلوتوثی قابل حمل پرومیت مدل Rustic-3       IT
# 53182      681083                                  هدفون کم مدل 1000       AC
# 53186      724421           کیف بازویی موبایل مناسب برای گوشی 6 اینچ       AC
# 53188      716840            \tساعت مچی عقربه ای زنانه والار مدل 002       FA
# 99999      451791             ماژیک علامت گذار 6 رنگ اسکای مدل S-905       MA
#
# ...

# %%
review_df[review_df['product_id'] == 406523]
# Out:
#        product_id                            product_title title_en  user_id  \
# 38121      406523  مجموعه قاشق، چنگال و چاقو سفری مدل K603       TS   722776
# 74156      406523  مجموعه قاشق، چنگال و چاقو سفری مدل K603       TS   764992
#
#        likes  dislikes verification_status    recommend          title  \
# 38121      0         0            verified           \N       بی کیفیت
# 74156      0         0            verified  recommended  کار راه انداز
#
#                                                  comment advantages  \
# 38121  نه کیفیت فلزش خوبه نه کیفیت ساختش مکانیزم داخی...        NaN
# 74156  کاربردی است , جنس در برابر قیمت قابل قبول است ...        NaN
#
#       disadvantages
# 38121           NaN
# 74156           NaN

# %%
order_hist_df[order_hist_df['product_id'] == 406523]
# Out:
#          order_id                   user_id  variant_id  product_id  quantity  \
# 0       262108413  SlcW7YT835JSzh22o7zRCA==      922274      406523         1
# 1287    262087149  btMCC1KIEY+gse42GnAcxA==      922274      406523         1
# 18129   261674961  5fuehPrY+8b+2hIvyo8gUA==      625920      406523         1
# 53229   261026385  lMXqMGR+QlCaaPIB/36fNg==      922274      406523         1
# 73293   260748129  m3COlvzqUGVat+Gx+Lglnw==      922274      406523         1
# 85106   260602389  PKJkMVorkhhVIZHCrChnfw==      922274      406523         1
# 135246  259827681  wA+MUb8JeV/+sjAvPZaXjg==     1194993      406523         1
# 167077  259329945  AF9uKWFA14wTaSdwgU2vHw==      922274      406523         1
# 194158  258928221  Bbq6w9maaIYWhEXQHp4n5Q==      922274      406523         1
#
#          price                 date  city_id  city_name  state_id state_name
# 0       139000  2018-08-20 23:59:02     1698      تهران         9      تهران
# ...

# %%
order_hist_df['user_id'].unique().size
# Out:
# 56104

# %%
review_df['user_id'].unique().size
# Out:
# 56692
