# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X, Y  = make_blobs(n_samples=500, centers = 5, random_state=3)

# %%
X.shape
# Out:
# (500, 2)

# %%
plt.grid(True)
plt.scatter(X[:,0], X[:, 1], c=Y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.unique(Y)
# Out:
# array([0, 1, 2, 3, 4])

# %%
print(np.min(X), np.max(X, axis=0))
# Out:
# -11.947781246268217 [ 9.94858796 11.24016602]

# %%
for k in range(2, 10):
    datapoints = X.shape[0]
    dimension = X.shape[1]
    centers = np.random.uniform(low = np.min(X), high = np.max(X), size = (k, dimension))
    clusters = {}
    
    for ix in range(datapoints):
        dist = []
        datapoint = X[ix]
        
        for center in range(k): dist.append(distance(center, datapoint))
        ic = np.argmax(dist)
        centers[ic]

# %%
np.random.uniform(low=-12, high=12, size=(2,2))[1]
# Out:
# array([-11.5845935 ,   7.05983908])

# %%
# Out:
# [-6.94238952 -6.8807223 ]
# [8.14492336 7.52724561]
# [-3.61995355 -0.07726913]
# [-8.91918262 -6.772189  ]
# [-7.37151112 -5.0506429 ]
# [-4.65743008  0.05077508]
# [-9.85614721 -1.94829844]
# [-7.03064028 -7.47212242]
# [7.44598269 9.20313614]
# [-6.74761638 -5.40793452]
# [8.73872704 5.97009465]
# [-3.8987193   0.15219193]
# [8.84851188 9.26501008]
# [-6.83038032 -7.68741713]
# [-4.65780461  0.51339663]
# [-9.14747586 -5.83583269]
# [8.27287322 6.92062212]
# [-6.67147607 -5.89031942]
# [-7.33837507 -5.9643993 ]
# [6.96905011 6.3449164 ]
# [1.87879015 3.51452443]
# [1.46173901 3.38024741]
# [-7.82304106 -6.34230341]
# [-3.78877994 -0.0248327 ]
# [-6.60607411 -5.67971605]
# [-0.22816528  3.53653954]
# [-10.3969262   -0.28827972]
# [-9.18719238 -0.47349654]
# [-4.45650534  0.65156136]
# [-8.11324217 -0.41686247]
# [-8.3795168  -6.85309235]
# [-10.22494442   0.16581105]
# [0.34123054 4.31357332]
# [0.42745643 2.61640063]
# [-8.78389426 -5.7223743 ]
# [0.14207575 4.19267027]
# ...
