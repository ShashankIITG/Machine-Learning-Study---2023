# %%
import gymnasium as gym
import random
import numpy as np
import pandas as pd
from collections import deque

from keras.models import Sequential
from keras.layers import Input, Dense, Dropout
from keras.optimizers import Adam

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array_list")

state_size, = env.observation_space.shape
action_size = env.action_space.n

gameover = False
episodes = 1_000

# %%
class Agent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.model = self._create_model()
        self.memory = deque(maxlen=2000)
        
        self.epsilon = 1.0
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.001
        self.gamma = 0.98
        
    def _create_model(self):
        model = Sequential()
        model.add(Input(self.state_size))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(24, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(optimizer=Adam(learning_rate=0.0001), loss='mse')
        return model
    
    def action(self, state):
        # random actions with epsilon chances
        if np.random.rand() <= self.epsilon:
            return env.action_space.sample()
        # predicted action based on NN (brain)
        else:
            return np.argmax(self.model.predict(state, 
                                                verbose=0, 
                                                use_multiprocessing=True)[0])
        
    def store(self, state, reward, gameover, next_state):
        experience = pd.DataFrame([[state, action, reward, gameover, next_state]],
                                  columns=['state', 'action', 'reward', 'gameover', 'next_state'])
        self.memory.append(experience)
        
    def train(self, buffer_size=64):
        """
        neural network model will be trained on env states (input) and predicted_qsa.
        objective - optimize the predicted_qsa to close to actual qsa
        predicted_qsa = reward + gamma * max(predicted_qs'a')
        """
        buffer = random.sample(self.memory, buffer_size) # this will return a list
        nexperience = pd.concat(buffer)
        
        # psa shape is (batch size, action size)
        qsa = np.where(nexperience.gameover, # where condition
                       nexperience.reward, # gameover is true
                       nexperience.reward + self.gamma * 
                       np.argmax(
                           self.model.predict(
                               np.vstack(nexperience.next_state),
                               verbose=0,),
                           axis=1))
    
        predicted_qsa = self.model.predict(np.vstack(nexperience.state),
                                           verbose=0, 
                                           use_multiprocessing=True)
        
        predicted_qsa[np.arange(buffer_size), np.vstack(nexperience.action)] = qsa
        
        self.model.fit(np.vstack(nexperience.state),
                       predicted_qsa,
                       epochs=1,
                       verbose=0,
                       use_multiprocessing=True)

# %%
agent = Agent(state_size, action_size)

# %%
agent.model.predict(env.reset()[0].reshape(1, -1)).shape
# Out:
# 1/1 [==============================] - 1s 1s/step
# (1, 2)

# %%
np.argmax(p, axis=1)
# Out:
# array([0], dtype=int64)

# %%
for e in range(episodes):
    state = env.reset()[0].reshape((1, -1))
    for time in range(1000):
        action = agent.action(state)
        next_state, reward, terminated, truncated, info = env.step(action)
        gameover = terminated | truncated
        # penalize reward
        if gameover: reward = -1
        # store experience
        next_state = next_state.reshape((1, -1)) # reshape next_state array before storing experience
        agent.store(state, reward, gameover, next_state)
        
        if gameover:
            print("Episode #{} of {} | score: {} | exploration rate: {:.2}".format(e, episodes, time, agent.epsilon))
            break
            
    if len(agent.memory) > 100:
        agent.train()
        
print("model trained")
# Out:
# Episode #0 of 1000 | score: 19 | exploration rate: 1.0
# Episode #1 of 1000 | score: 11 | exploration rate: 1.0
# Episode #2 of 1000 | score: 17 | exploration rate: 1.0
# Episode #3 of 1000 | score: 43 | exploration rate: 1.0
# Episode #4 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #5 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #6 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #7 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #8 of 1000 | score: 40 | exploration rate: 1.0
# done
# Episode #9 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #10 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #11 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #12 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #13 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #14 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #15 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #16 of 1000 | score: 59 | exploration rate: 1.0
# done
# Episode #17 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #18 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #19 of 1000 | score: 35 | exploration rate: 1.0
# done
# Episode #20 of 1000 | score: 57 | exploration rate: 1.0
# done
# Episode #21 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #22 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #23 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #24 of 1000 | score: 52 | exploration rate: 1.0
# done
# Episode #25 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #26 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #27 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #28 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #29 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #30 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #31 of 1000 | score: 46 | exploration rate: 1.0
# done
# Episode #32 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #33 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #34 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #35 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #36 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #37 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #38 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #39 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #40 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #41 of 1000 | score: 47 | exploration rate: 1.0
# done
# Episode #42 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #43 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #44 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #45 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #46 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #47 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #48 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #49 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #50 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #51 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #52 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #53 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #54 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #55 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #56 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #57 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #58 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #59 of 1000 | score: 42 | exploration rate: 1.0
# done
# Episode #60 of 1000 | score: 51 | exploration rate: 1.0
# done
# Episode #61 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #62 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #63 of 1000 | score: 36 | exploration rate: 1.0
# done
# Episode #64 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #65 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #66 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #67 of 1000 | score: 52 | exploration rate: 1.0
# done
# Episode #68 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #69 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #70 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #71 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #72 of 1000 | score: 89 | exploration rate: 1.0
# done
# Episode #73 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #74 of 1000 | score: 41 | exploration rate: 1.0
# done
# Episode #75 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #76 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #77 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #78 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #79 of 1000 | score: 40 | exploration rate: 1.0
# done
# Episode #80 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #81 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #82 of 1000 | score: 48 | exploration rate: 1.0
# done
# Episode #83 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #84 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #85 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #86 of 1000 | score: 34 | exploration rate: 1.0
# done
# Episode #87 of 1000 | score: 56 | exploration rate: 1.0
# done
# Episode #88 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #89 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #90 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #91 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #92 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #93 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #94 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #95 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #96 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #97 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #98 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #99 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #100 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #101 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #102 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #103 of 1000 | score: 34 | exploration rate: 1.0
# done
# Episode #104 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #105 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #106 of 1000 | score: 51 | exploration rate: 1.0
# done
# Episode #107 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #108 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #109 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #110 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #111 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #112 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #113 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #114 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #115 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #116 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #117 of 1000 | score: 47 | exploration rate: 1.0
# done
# Episode #118 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #119 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #120 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #121 of 1000 | score: 7 | exploration rate: 1.0
# done
# Episode #122 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #123 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #124 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #125 of 1000 | score: 46 | exploration rate: 1.0
# done
# Episode #126 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #127 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #128 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #129 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #130 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #131 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #132 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #133 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #134 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #135 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #136 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #137 of 1000 | score: 58 | exploration rate: 1.0
# done
# Episode #138 of 1000 | score: 35 | exploration rate: 1.0
# done
# Episode #139 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #140 of 1000 | score: 57 | exploration rate: 1.0
# done
# Episode #141 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #142 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #143 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #144 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #145 of 1000 | score: 114 | exploration rate: 1.0
# done
# Episode #146 of 1000 | score: 37 | exploration rate: 1.0
# done
# Episode #147 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #148 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #149 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #150 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #151 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #152 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #153 of 1000 | score: 41 | exploration rate: 1.0
# done
# Episode #154 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #155 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #156 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #157 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #158 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #159 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #160 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #161 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #162 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #163 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #164 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #165 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #166 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #167 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #168 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #169 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #170 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #171 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #172 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #173 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #174 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #175 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #176 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #177 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #178 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #179 of 1000 | score: 40 | exploration rate: 1.0
# done
# Episode #180 of 1000 | score: 34 | exploration rate: 1.0
# done
# Episode #181 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #182 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #183 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #184 of 1000 | score: 36 | exploration rate: 1.0
# done
# Episode #185 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #186 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #187 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #188 of 1000 | score: 39 | exploration rate: 1.0
# done
# Episode #189 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #190 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #191 of 1000 | score: 35 | exploration rate: 1.0
# done
# Episode #192 of 1000 | score: 67 | exploration rate: 1.0
# done
# Episode #193 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #194 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #195 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #196 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #197 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #198 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #199 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #200 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #201 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #202 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #203 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #204 of 1000 | score: 42 | exploration rate: 1.0
# done
# Episode #205 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #206 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #207 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #208 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #209 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #210 of 1000 | score: 49 | exploration rate: 1.0
# done
# Episode #211 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #212 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #213 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #214 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #215 of 1000 | score: 37 | exploration rate: 1.0
# done
# Episode #216 of 1000 | score: 50 | exploration rate: 1.0
# done
# Episode #217 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #218 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #219 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #220 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #221 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #222 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #223 of 1000 | score: 79 | exploration rate: 1.0
# done
# Episode #224 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #225 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #226 of 1000 | score: 47 | exploration rate: 1.0
# done
# Episode #227 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #228 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #229 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #230 of 1000 | score: 41 | exploration rate: 1.0
# done
# Episode #231 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #232 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #233 of 1000 | score: 40 | exploration rate: 1.0
# done
# Episode #234 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #235 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #236 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #237 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #238 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #239 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #240 of 1000 | score: 59 | exploration rate: 1.0
# done
# Episode #241 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #242 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #243 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #244 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #245 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #246 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #247 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #248 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #249 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #250 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #251 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #252 of 1000 | score: 41 | exploration rate: 1.0
# done
# Episode #253 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #254 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #255 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #256 of 1000 | score: 62 | exploration rate: 1.0
# done
# Episode #257 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #258 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #259 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #260 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #261 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #262 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #263 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #264 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #265 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #266 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #267 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #268 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #269 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #270 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #271 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #272 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #273 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #274 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #275 of 1000 | score: 47 | exploration rate: 1.0
# done
# Episode #276 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #277 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #278 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #279 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #280 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #281 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #282 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #283 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #284 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #285 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #286 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #287 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #288 of 1000 | score: 40 | exploration rate: 1.0
# done
# Episode #289 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #290 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #291 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #292 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #293 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #294 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #295 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #296 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #297 of 1000 | score: 42 | exploration rate: 1.0
# done
# Episode #298 of 1000 | score: 37 | exploration rate: 1.0
# done
# Episode #299 of 1000 | score: 33 | exploration rate: 1.0
# done
# Episode #300 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #301 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #302 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #303 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #304 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #305 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #306 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #307 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #308 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #309 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #310 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #311 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #312 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #313 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #314 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #315 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #316 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #317 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #318 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #319 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #320 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #321 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #322 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #323 of 1000 | score: 42 | exploration rate: 1.0
# done
# Episode #324 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #325 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #326 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #327 of 1000 | score: 35 | exploration rate: 1.0
# done
# Episode #328 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #329 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #330 of 1000 | score: 33 | exploration rate: 1.0
# done
# Episode #331 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #332 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #333 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #334 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #335 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #336 of 1000 | score: 35 | exploration rate: 1.0
# done
# Episode #337 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #338 of 1000 | score: 43 | exploration rate: 1.0
# done
# Episode #339 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #340 of 1000 | score: 55 | exploration rate: 1.0
# done
# Episode #341 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #342 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #343 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #344 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #345 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #346 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #347 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #348 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #349 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #350 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #351 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #352 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #353 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #354 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #355 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #356 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #357 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #358 of 1000 | score: 34 | exploration rate: 1.0
# done
# Episode #359 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #360 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #361 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #362 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #363 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #364 of 1000 | score: 45 | exploration rate: 1.0
# done
# Episode #365 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #366 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #367 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #368 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #369 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #370 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #371 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #372 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #373 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #374 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #375 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #376 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #377 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #378 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #379 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #380 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #381 of 1000 | score: 43 | exploration rate: 1.0
# done
# Episode #382 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #383 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #384 of 1000 | score: 52 | exploration rate: 1.0
# done
# Episode #385 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #386 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #387 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #388 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #389 of 1000 | score: 53 | exploration rate: 1.0
# done
# Episode #390 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #391 of 1000 | score: 33 | exploration rate: 1.0
# done
# Episode #392 of 1000 | score: 66 | exploration rate: 1.0
# done
# Episode #393 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #394 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #395 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #396 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #397 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #398 of 1000 | score: 42 | exploration rate: 1.0
# done
# Episode #399 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #400 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #401 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #402 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #403 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #404 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #405 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #406 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #407 of 1000 | score: 34 | exploration rate: 1.0
# done
# Episode #408 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #409 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #410 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #411 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #412 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #413 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #414 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #415 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #416 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #417 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #418 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #419 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #420 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #421 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #422 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #423 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #424 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #425 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #426 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #427 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #428 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #429 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #430 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #431 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #432 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #433 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #434 of 1000 | score: 48 | exploration rate: 1.0
# done
# Episode #435 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #436 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #437 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #438 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #439 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #440 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #441 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #442 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #443 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #444 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #445 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #446 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #447 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #448 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #449 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #450 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #451 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #452 of 1000 | score: 33 | exploration rate: 1.0
# done
# Episode #453 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #454 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #455 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #456 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #457 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #458 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #459 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #460 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #461 of 1000 | score: 45 | exploration rate: 1.0
# done
# Episode #462 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #463 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #464 of 1000 | score: 40 | exploration rate: 1.0
# done
# Episode #465 of 1000 | score: 40 | exploration rate: 1.0
# done
# Episode #466 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #467 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #468 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #469 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #470 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #471 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #472 of 1000 | score: 49 | exploration rate: 1.0
# done
# Episode #473 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #474 of 1000 | score: 48 | exploration rate: 1.0
# done
# Episode #475 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #476 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #477 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #478 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #479 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #480 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #481 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #482 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #483 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #484 of 1000 | score: 44 | exploration rate: 1.0
# done
# Episode #485 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #486 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #487 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #488 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #489 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #490 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #491 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #492 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #493 of 1000 | score: 59 | exploration rate: 1.0
# done
# Episode #494 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #495 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #496 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #497 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #498 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #499 of 1000 | score: 33 | exploration rate: 1.0
# done
# Episode #500 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #501 of 1000 | score: 34 | exploration rate: 1.0
# done
# Episode #502 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #503 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #504 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #505 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #506 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #507 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #508 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #509 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #510 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #511 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #512 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #513 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #514 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #515 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #516 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #517 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #518 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #519 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #520 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #521 of 1000 | score: 45 | exploration rate: 1.0
# done
# Episode #522 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #523 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #524 of 1000 | score: 45 | exploration rate: 1.0
# done
# Episode #525 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #526 of 1000 | score: 37 | exploration rate: 1.0
# done
# Episode #527 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #528 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #529 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #530 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #531 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #532 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #533 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #534 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #535 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #536 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #537 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #538 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #539 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #540 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #541 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #542 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #543 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #544 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #545 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #546 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #547 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #548 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #549 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #550 of 1000 | score: 62 | exploration rate: 1.0
# done
# Episode #551 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #552 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #553 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #554 of 1000 | score: 52 | exploration rate: 1.0
# done
# Episode #555 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #556 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #557 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #558 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #559 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #560 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #561 of 1000 | score: 35 | exploration rate: 1.0
# done
# Episode #562 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #563 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #564 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #565 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #566 of 1000 | score: 44 | exploration rate: 1.0
# done
# Episode #567 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #568 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #569 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #570 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #571 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #572 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #573 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #574 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #575 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #576 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #577 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #578 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #579 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #580 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #581 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #582 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #583 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #584 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #585 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #586 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #587 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #588 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #589 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #590 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #591 of 1000 | score: 39 | exploration rate: 1.0
# done
# Episode #592 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #593 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #594 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #595 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #596 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #597 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #598 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #599 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #600 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #601 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #602 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #603 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #604 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #605 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #606 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #607 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #608 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #609 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #610 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #611 of 1000 | score: 48 | exploration rate: 1.0
# done
# Episode #612 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #613 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #614 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #615 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #616 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #617 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #618 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #619 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #620 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #621 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #622 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #623 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #624 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #625 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #626 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #627 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #628 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #629 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #630 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #631 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #632 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #633 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #634 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #635 of 1000 | score: 33 | exploration rate: 1.0
# done
# Episode #636 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #637 of 1000 | score: 35 | exploration rate: 1.0
# done
# Episode #638 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #639 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #640 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #641 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #642 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #643 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #644 of 1000 | score: 61 | exploration rate: 1.0
# done
# Episode #645 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #646 of 1000 | score: 35 | exploration rate: 1.0
# done
# Episode #647 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #648 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #649 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #650 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #651 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #652 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #653 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #654 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #655 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #656 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #657 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #658 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #659 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #660 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #661 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #662 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #663 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #664 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #665 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #666 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #667 of 1000 | score: 16 | exploration rate: 1.0
# done
# Episode #668 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #669 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #670 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #671 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #672 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #673 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #674 of 1000 | score: 39 | exploration rate: 1.0
# done
# Episode #675 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #676 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #677 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #678 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #679 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #680 of 1000 | score: 42 | exploration rate: 1.0
# done
# Episode #681 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #682 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #683 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #684 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #685 of 1000 | score: 51 | exploration rate: 1.0
# done
# Episode #686 of 1000 | score: 40 | exploration rate: 1.0
# done
# Episode #687 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #688 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #689 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #690 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #691 of 1000 | score: 56 | exploration rate: 1.0
# done
# Episode #692 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #693 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #694 of 1000 | score: 49 | exploration rate: 1.0
# done
# Episode #695 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #696 of 1000 | score: 33 | exploration rate: 1.0
# done
# Episode #697 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #698 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #699 of 1000 | score: 42 | exploration rate: 1.0
# done
# Episode #700 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #701 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #702 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #703 of 1000 | score: 92 | exploration rate: 1.0
# done
# Episode #704 of 1000 | score: 66 | exploration rate: 1.0
# done
# Episode #705 of 1000 | score: 7 | exploration rate: 1.0
# done
# Episode #706 of 1000 | score: 42 | exploration rate: 1.0
# done
# Episode #707 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #708 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #709 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #710 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #711 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #712 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #713 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #714 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #715 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #716 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #717 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #718 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #719 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #720 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #721 of 1000 | score: 39 | exploration rate: 1.0
# done
# Episode #722 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #723 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #724 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #725 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #726 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #727 of 1000 | score: 47 | exploration rate: 1.0
# done
# Episode #728 of 1000 | score: 34 | exploration rate: 1.0
# done
# Episode #729 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #730 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #731 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #732 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #733 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #734 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #735 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #736 of 1000 | score: 26 | exploration rate: 1.0
# done
# Episode #737 of 1000 | score: 34 | exploration rate: 1.0
# done
# Episode #738 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #739 of 1000 | score: 7 | exploration rate: 1.0
# done
# Episode #740 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #741 of 1000 | score: 39 | exploration rate: 1.0
# done
# Episode #742 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #743 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #744 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #745 of 1000 | score: 41 | exploration rate: 1.0
# done
# Episode #746 of 1000 | score: 75 | exploration rate: 1.0
# done
# Episode #747 of 1000 | score: 59 | exploration rate: 1.0
# done
# Episode #748 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #749 of 1000 | score: 32 | exploration rate: 1.0
# done
# Episode #750 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #751 of 1000 | score: 33 | exploration rate: 1.0
# done
# Episode #752 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #753 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #754 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #755 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #756 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #757 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #758 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #759 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #760 of 1000 | score: 39 | exploration rate: 1.0
# done
# Episode #761 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #762 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #763 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #764 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #765 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #766 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #767 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #768 of 1000 | score: 19 | exploration rate: 1.0
# done
# Episode #769 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #770 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #771 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #772 of 1000 | score: 20 | exploration rate: 1.0
# done
# Episode #773 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #774 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #775 of 1000 | score: 28 | exploration rate: 1.0
# done
# Episode #776 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #777 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #778 of 1000 | score: 24 | exploration rate: 1.0
# done
# Episode #779 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #780 of 1000 | score: 29 | exploration rate: 1.0
# done
# Episode #781 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #782 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #783 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #784 of 1000 | score: 30 | exploration rate: 1.0
# done
# Episode #785 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #786 of 1000 | score: 25 | exploration rate: 1.0
# done
# Episode #787 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #788 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #789 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #790 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #791 of 1000 | score: 31 | exploration rate: 1.0
# done
# Episode #792 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #793 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #794 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #795 of 1000 | score: 17 | exploration rate: 1.0
# done
# Episode #796 of 1000 | score: 15 | exploration rate: 1.0
# done
# Episode #797 of 1000 | score: 14 | exploration rate: 1.0
# done
# Episode #798 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #799 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #800 of 1000 | score: 10 | exploration rate: 1.0
# done
# Episode #801 of 1000 | score: 8 | exploration rate: 1.0
# done
# Episode #802 of 1000 | score: 13 | exploration rate: 1.0
# done
# Episode #803 of 1000 | score: 12 | exploration rate: 1.0
# done
# Episode #804 of 1000 | score: 38 | exploration rate: 1.0
# done
# Episode #805 of 1000 | score: 22 | exploration rate: 1.0
# done
# Episode #806 of 1000 | score: 21 | exploration rate: 1.0
# done
# Episode #807 of 1000 | score: 11 | exploration rate: 1.0
# done
# Episode #808 of 1000 | score: 27 | exploration rate: 1.0
# done
# Episode #809 of 1000 | score: 23 | exploration rate: 1.0
# done
# Episode #810 of 1000 | score: 9 | exploration rate: 1.0
# done
# Episode #811 of 1000 | score: 18 | exploration rate: 1.0
# done
# Episode #812 of 1000 | score: 24 | exploration rate: 1.0
# done
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "Z:\Google\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-276-4f3c52543ba0>", line 18, in <module>
#     agent.train()
#   File "<ipython-input-274-cf716cc31ce5>", line 58, in train
#     predicted_qsa = self.model.predict(np.vstack(nexperience.state),
#   File "Z:\Google\Anaconda\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#     return fn(*args, **kwargs)
#   File "Z:\Google\Anaconda\lib\site-packages\keras\engine\training.py", line 2220, in predict
#     data_handler = data_adapter.get_data_handler(
#   File "Z:\Google\Anaconda\lib\site-packages\keras\engine\data_adapter.py", line 1582, in get_data_handler
#     return DataHandler(*args, **kwargs)
#   File "Z:\Google\Anaconda\lib\site-packages\keras\engine\data_adapter.py", line 1262, in __init__
#     self._adapter = adapter_cls(
#   File "Z:\Google\Anaconda\lib\site-packages\keras\engine\data_adapter.py", line 347, in __init__
#     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 2245, in flat_map
#     return FlatMapDataset(self, map_func, name=name)
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 5484, in __init__
#     self._map_func = structured_function.StructuredFunctionWrapper(
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\data\ops\structured_function.py", line 271, in __init__
#     self._function = fn_factory()
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\eager\function.py", line 2610, in get_concrete_function
#     graph_function = self._get_concrete_function_garbage_collected(
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\eager\function.py", line 2576, in _get_concrete_function_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\eager\function.py", line 2760, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\eager\function.py", line 2670, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1144, in func_graph_from_py_func
#     func_graph = FuncGraph(
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\framework\func_graph.py", line 230, in __init__
#     super(FuncGraph, self).__init__()
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py", line 3214, in __init__
#     self._c_graph = c_api_util.ScopedTFGraph(self._graph_key)
#   File "Z:\Google\Anaconda\lib\site-packages\tensorflow\python\framework\c_api_util.py", line 97, in __init__
#     name, obj=c_api.TF_NewGraph(), deleter=c_api.TF_DeleteGraph)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "Z:\Google\Anaconda\lib\site-packages\IPython\core\interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "Z:\Google\Anaconda\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "Z:\Google\Anaconda\lib\inspect.py", line 1465, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py", line 170, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "Z:\Google\Anaconda\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "Z:\Google\Anaconda\lib\inspect.py", line 745, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-276-4f3c52543ba0> in <module>
#      17     if len(agent.memory) > 100:
# ---> 18         agent.train()
#      19
#
# <ipython-input-274-cf716cc31ce5> in train(self, buffer_size)
#      57
# ---> 58         predicted_qsa = self.model.predict(np.vstack(nexperience.state),
#      59                                            verbose=0,
#
# Z:\Google\Anaconda\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#
# Z:\Google\Anaconda\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2219
# -> 2220             data_handler = data_adapter.get_data_handler(
#    2221                 x=x,
#
# Z:\Google\Anaconda\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1581         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1582     return DataHandler(*args, **kwargs)
#    1583
#
# Z:\Google\Anaconda\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1261         adapter_cls = select_data_adapter(x, y)
# -> 1262         self._adapter = adapter_cls(
#    1263             x,
#
# Z:\Google\Anaconda\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     346
# --> 347         indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     348
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in flat_map(self, map_func, name)
#    2244     """
# -> 2245     return FlatMapDataset(self, map_func, name=name)
#    2246
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, name)
#    5483     self._input_dataset = input_dataset
# -> 5484     self._map_func = structured_function.StructuredFunctionWrapper(
#    5485         map_func, self._transformation_name(), dataset=input_dataset)
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\data\ops\structured_function.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     270
# --> 271     self._function = fn_factory()
#     272     # There is no graph to add in eager mode.
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    2609     """
# -> 2610     graph_function = self._get_concrete_function_garbage_collected(
#    2611         *args, **kwargs)
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2575     with self._lock:
# -> 2576       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2577       seen_names = set()
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    2759             args, kwargs = placeholder_dict["args"]
# -> 2760           graph_function = self._create_graph_function(args, kwargs)
#    2761
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs)
#    2669     graph_function = ConcreteFunction(
# -> 2670         func_graph_module.func_graph_from_py_func(
#    2671             self._name,
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1143   if func_graph is None:
# -> 1144     func_graph = FuncGraph(
#    1145         name, collections=collections, capture_by_value=capture_by_value)
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\framework\func_graph.py in __init__(self, name, collections, capture_by_value, structured_input_signature, structured_outputs)
#     229     """
# --> 230     super(FuncGraph, self).__init__()
#     231     self.name = name
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self)
#    3213     # implementation
# -> 3214     self._c_graph = c_api_util.ScopedTFGraph(self._graph_key)
#    3215     # The C API requires all ops to have shape functions. Disable this
#
# Z:\Google\Anaconda\lib\site-packages\tensorflow\python\framework\c_api_util.py in __init__(self, name)
#      96     super(ScopedTFGraph, self).__init__(
# ---> 97         name, obj=c_api.TF_NewGraph(), deleter=c_api.TF_DeleteGraph)
#      98
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Z:\Google\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Z:\Google\Anaconda\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                         stb = value._render_traceback_()
#    2046                     except Exception:
# -> 2047                         stb = self.InteractiveTB.structured_traceback(etype,
#    2048                                             value, tb, tb_offset=tb_offset)
#    2049
#
# Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434         else:
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334         if mode in self.verbose_modes:
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191         """Return a nice text document describing the traceback."""
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#    1195
#
# Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# Z:\Google\Anaconda\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
f, ff = agent.train()
# Out:
# done
# 2/2 [==============================] - 0s 36ms/step

# %%
ff.shape
# Out:
# (64, 2)

# %%
f[0:4]
# Out:
# array([1.98, 1.  , 1.98, 1.98])

# %%
g = f
g[g!=1.] = 0
g = np.asarray(g, dtype=int)

# %%
ff[0, g] =

# %%
np.amax(ff, axis=1)
# Out:
# array([ 0.00201042, -0.00918985, -0.00918985,  0.00067103,  0.00961511,
#         0.00201042, -0.00918985,  0.00201042,  0.01340952,  0.00961511,
#         0.01592626,  0.01340952,  0.00067103, -0.00918985, -0.00918985,
#         0.00201042, -0.00918985,  0.00201042,  0.00067103, -0.00918985,
#         0.00201042,  0.00961511, -0.00918985,  0.01592626, -0.00918985,
#         0.00201042,  0.00201042, -0.00918985,  0.00067103,  0.00201042,
#         0.00067103,  0.00067103,  0.01340952,  0.01340952,  0.01340952,
#         0.01340952,  0.00201042, -0.00918985, -0.00918985, -0.00918985,
#         0.01340952,  0.00201042, -0.00918985,  0.00201042,  0.00201042,
#         0.00201042,  0.01592626,  0.00961511,  0.00067103,  0.00067103,
#         0.00201042,  0.00201042,  0.01340952,  0.00201042,  0.00201042,
#         0.01592626, -0.00918985,  0.01592626,  0.00961511, -0.00918985,
#         0.00067103,  0.00201042, -0.00918985,  0.00067103], dtype=float32)

# %%
np.max(ff, axis=1)
# Out:
# array([ 0.00201042, -0.00918985, -0.00918985,  0.00067103,  0.00961511,
#         0.00201042, -0.00918985,  0.00201042,  0.01340952,  0.00961511,
#         0.01592626,  0.01340952,  0.00067103, -0.00918985, -0.00918985,
#         0.00201042, -0.00918985,  0.00201042,  0.00067103, -0.00918985,
#         0.00201042,  0.00961511, -0.00918985,  0.01592626, -0.00918985,
#         0.00201042,  0.00201042, -0.00918985,  0.00067103,  0.00201042,
#         0.00067103,  0.00067103,  0.01340952,  0.01340952,  0.01340952,
#         0.01340952,  0.00201042, -0.00918985, -0.00918985, -0.00918985,
#         0.01340952,  0.00201042, -0.00918985,  0.00201042,  0.00201042,
#         0.00201042,  0.01592626,  0.00961511,  0.00067103,  0.00067103,
#         0.00201042,  0.00201042,  0.01340952,  0.00201042,  0.00201042,
#         0.01592626, -0.00918985,  0.01592626,  0.00961511, -0.00918985,
#         0.00067103,  0.00201042, -0.00918985,  0.00067103], dtype=float32)
